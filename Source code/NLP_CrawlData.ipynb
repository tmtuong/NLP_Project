# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 3.1 MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.4.3.20220106

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import datetime as dt

keywords = ['"want to buy"', '"need to buy"'] 
x = dt.date.today()
tweets = []

for i in keywords:

  query = f"({i}) lang:en  until:{x} since:{x- dt.timedelta(days = 90)}"
  limit = 25000
  tweets_keyword = []

  for tweet in sntwitter.TwitterSearchScraper(query).get_items():
      
      if len(tweets_keyword) < limit:
        tweets_keyword.append([tweet.date, tweet.username, tweet.content])
      else:
        for k in tweets_keyword:
          tweets.append(k)
        break
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(len(df))
# Out:
# <ipython-input-3-ae4b830bc224>:18: FutureWarning: username is deprecated, use user.username instead
#   tweets_keyword.append([tweet.date, tweet.username, tweet.content])
# 20000

# %%
df
# Out:
#                            Date             User  \
# 0     2022-12-13 23:59:59+00:00        NastySkip
# 1     2022-12-13 23:59:59+00:00         xkeyxkey
# 2     2022-12-13 23:59:57+00:00         dr_stock
# 3     2022-12-13 23:59:54+00:00    streamed_hams
# 4     2022-12-13 23:59:54+00:00     ChrisMifflin
# ...                         ...              ...
# 19995 2022-12-13 15:31:02+00:00     citizen_mint
# 19996 2022-12-13 15:30:58+00:00    OptionsProVol
# 19997 2022-12-13 15:30:57+00:00  StocksoftheDay_
# 19998 2022-12-13 15:30:55+00:00       capitol2iq
# 19999 2022-12-13 15:30:53+00:00     Nobunaga0804
#
#                                                    Tweet
# 0      OMG. 😂🤣😂 Am I literally getting trolled. This ...
# 1      None of them could go anywhere without tires. ...
# 2      @StephenKing She reminds me of that doofus rab...
# 3      @i_loathe_tweets must suck to have borrowed mo...
# 4      @Izziebettz2 @RBReich The $29.01 is what each ...
# ...                                                  ...
# 19995  With stocks and bonds on track for the worst y...
# 19996  $HOV company #profile, #Fundamental and #Techn...
# 19997  SaverOne Wins Follow-on Contract with ReadyMix...
# 19998  According to his disclosure, Senator @RonWyden...
# 19999  Pandemic gains in American wealth are melting ...
#
# [20000 rows x 3 columns]

# %%
df.to_csv('/content/twitter_tweet.csv')
