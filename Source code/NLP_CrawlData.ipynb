# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 59 kB 2.1 MB/s
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import datetime as dt

keywords = ['"want to buy"', '"need to buy"'] 
x = dt.date.today()
tweets = []

for i in keywords:

  query = f"({i}) lang:en  until:{x} since:{x- dt.timedelta(days = 90)}"
  limit = 25000
  tweets_keyword = []

  for tweet in sntwitter.TwitterSearchScraper(query).get_items():
      
      if len(tweets_keyword) < limit:
        tweets_keyword.append([tweet.date, tweet.username, tweet.content])
      else:
        for k in tweets_keyword:
          tweets.append(k)
        break
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(len(df))
# Out:
# <ipython-input-2-1f367178e1b2>:18: FutureWarning: username is deprecated, use user.username instead
#   tweets_keyword.append([tweet.date, tweet.username, tweet.content])
# 50000

# %%
df
# Out:
#                            Date             User  \
# 0     2022-12-14 23:59:44+00:00         Lord_Fez
# 1     2022-12-14 23:58:51+00:00   BrookieNightly
# 2     2022-12-14 23:57:06+00:00   spradlin_terry
# 3     2022-12-14 23:56:56+00:00    thequeeen_bee
# 4     2022-12-14 23:55:46+00:00     MasGanteng66
# ...                         ...              ...
# 49995 2022-12-02 13:51:09+00:00       advisorrob
# 49996 2022-12-02 13:50:52+00:00    De_Prince_505
# 49997 2022-12-02 13:50:29+00:00       Opara1Ivan
# 49998 2022-12-02 13:50:11+00:00  O86212678Samuel
# 49999 2022-12-02 13:50:08+00:00       samson7619
#
#                                                    Tweet
# 0      There are so many games I want to buy that loo...
# 1                 just want to buy all my Poshmark likes
# 2      @Kentucky_Hockey I want to buy a Kentucky hock...
# 3      I literally want to buy pachi everything I see...
# 4      @Tap_Fintech @Poundtoken I want to buy some st...
# ...

# %%
df.to_csv('/content/twitter_tweet.csv')
